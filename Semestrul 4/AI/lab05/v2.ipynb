# %%
# %run liniarRegession.ipynb
# %run liniarRegessionCustom.ipynb
# %run liniarRegessionMulti.ipynb

# %%
predictLiniarRegression("v2_world-happiness-report-2017.csv",
                        "Economy..GDP.per.Capita.",
                        "Happiness.Score",
                        "GDP",
                        "Happiness")

# %%
predictLiniarRegressionCustom("v2_world-happiness-report-2017.csv",
                        "Economy..GDP.per.Capita.",
                        "Happiness.Score",
                        "GDP",
                        "Happiness")

# %%
predictLiniarRegression("v2_world-happiness-report-2017.csv",
                        "Family",
                        "Happiness.Score",
                        "Family",
                        "Happiness")

# %%
predictLiniarRegressionMulti("v2_world-happiness-report-2017.csv",
                             "Economy..GDP.per.Capita.","Freedom",
                             "Happiness.Score",
                             "GDP", "Freedom",
                             "Happiness")
