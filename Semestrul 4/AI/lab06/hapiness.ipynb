# %%
# %run liniarRegessionGD.ipynb
# %run liniarRegessionMultiGD.ipynb

# %%
predictLiniarRegression("world-happiness-report-2017.csv",
                        "Economy..GDP.per.Capita.",
                        "Happiness.Score",
                        "GDP",
                        "Happiness")
# Out:
# prediction error (manual):  0.6599535069828703
# prediction error (tool):  0.6599535069828704

# %%
predictLiniarRegressionMulti("world-happiness-report-2017.csv",
                        "Economy..GDP.per.Capita.", "Freedom",
                        "Happiness.Score",
                        "GDP", "Freedom",
                        "Happiness")
