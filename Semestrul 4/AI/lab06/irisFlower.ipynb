# %%
# %run irisFlowerRegression.ipynb

# %%
regressor = predictLiniarRegressionMulti("iris.data",
                                         "Sepal area","Petal area",
                                         "Class",
                                         "Sepal area", "Petal area",
                                         "Class")

# %%
irisMap = {
    'Iris-setosa': 0,
    'Iris-versicolor': 1,
    'Iris-virginica': 2
}
target = min(round(regressor.predict_single([1.25, 0.4])), 2)
for key, value in irisMap.items():
    if value == target:
        print(key)
# Out:
# Iris-setosa
