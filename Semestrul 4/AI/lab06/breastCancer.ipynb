# %%
# %run breastCancerRegression.ipynb

# %%
regressor = predictLiniarRegressionMulti("wdbc.data",
                             "Radius","Texture",
                             "Diagnosis",
                             "Radius", "Texture",
                             "Diagnosis")

# %%
["M" if regressor.predict_single([10, 18]) >= 0.5 else "B"]
# Out:
# ['B']
